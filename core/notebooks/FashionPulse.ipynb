# %%
# !git clone https://github.com/DLochmelis33/fashion.pulse.git
# !git checkout multilabel
# !git restore .
# !git reset --hard origin/multilabel
# Out:
# Already on 'multilabel'
# Your branch is up to date with 'origin/multilabel'.

# %%
# %cd fashion.pulse/core/src/
# !ls
# Out:
# /content/fashion.pulse/core/src
# data  __init__.py  models  requirements.txt  utils

# %%
# %pip install pytorch-lightning
# %pip install wandb
# %pip install py7zr

# %%
# !wandb login
# Out:
# wandb: Currently logged in as: dlochmelis (dlhf). Use `wandb login --relogin` to force relogin

# %%
# %env DATA_DIR=/content/fashion.pulse/core/data
# %env ARTIFACTS_DIR=/content/fashion.pulse/core/artifacts
# Out:
# env: DATA_DIR=/content/fashion.pulse/core/data
# env: ARTIFACTS_DIR=/content/fashion.pulse/core/artifacts

# %%
# %run -m models.train
# Out:
# wandb: Currently logged in as: dlochmelis (dlhf). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.1
# Run data is saved locally in <code>/content/fashion.pulse/core/artifacts/wandb/wandb/run-20231206_175717-sg3yeobh</code>
# Syncing run <strong><a href='https://wandb.ai/dlhf/fashion.pulse-core_src/runs/sg3yeobh' target="_blank">wobbly-plant-20</a></strong> to <a href='https://wandb.ai/dlhf/fashion.pulse-core_src' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/dlhf/fashion.pulse-core_src' target="_blank">https://wandb.ai/dlhf/fashion.pulse-core_src</a>
#  View run at <a href='https://wandb.ai/dlhf/fashion.pulse-core_src/runs/sg3yeobh' target="_blank">https://wandb.ai/dlhf/fashion.pulse-core_src/runs/sg3yeobh</a>
# ...

# %%
# don't forget to set up wandb_run_id and checkpoint in test.py
# %run -m models.test
# Out:
# wandb: Currently logged in as: dlochmelis (dlhf). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.1
# Run data is saved locally in <code>/content/fashion.pulse/core/artifacts/wandb/wandb/run-20231206_212139-sg3yeobh</code>
# Resuming run <strong><a href='https://wandb.ai/dlhf/fashion.pulse-core_src/runs/sg3yeobh' target="_blank">wobbly-plant-20</a></strong> to <a href='https://wandb.ai/dlhf/fashion.pulse-core_src' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/dlhf/fashion.pulse-core_src' target="_blank">https://wandb.ai/dlhf/fashion.pulse-core_src</a>
#  View run at <a href='https://wandb.ai/dlhf/fashion.pulse-core_src/runs/sg3yeobh' target="_blank">https://wandb.ai/dlhf/fashion.pulse-core_src/runs/sg3yeobh</a>
# ...

# %%
# %run -m models.predict
# Out:
# {'70s': 1.3602896160591627e-06, '80s_new-wave': 1.0121232662640978e-05, 'bohemian': 1.9787516066571698e-05, 'casual': 2.4355787786589644e-07, 'classic': 4.54908877145499e-06, 'flapper': 9.87775820249226e-06, 'formal': 5.7483266573399305e-06, 'glamorous': 3.2722546166041866e-05, 'gothic': 0.9958305954933167, 'grunge_punk-rock': 0.0013942900113761425, 'minimalist': 7.289969516932615e-07, 'neon': 9.513677845518487e-09, 'old-hollywood': 1.0187538464379031e-05, 'preppy_ivy-league': 2.057595793303335e-06, 'rock-n-roll': 0.00016359474102500826, 'sport': 7.381614750556764e-07, 'streetwear': 8.161581718013622e-06, 'techwear': 3.7104646253283136e-06, 'vintage': 3.799363548750989e-05, 'western': 5.9752037486759946e-06}

# %% [markdown]
# # TODO!
# 1. labels in predict
# 2. все в single class (лосс и аккураси)
# 3. прикрутить к серверу
# 4. readme + преза
